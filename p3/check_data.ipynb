# %%
import pandas as pd
import numpy as np
from PIL import Image
import math

# %%
vertices = pd.read_csv('face-vertices.data', header=None, names=['x', 'y', 'z'])

# %%
indices = pd.read_csv('face-index.txt', header=None, names=['p1', 'p2', 'p3'])

# %%
vertices.min()
# Out:
# 0   -0.272844
# 1   -0.500000
# 2   -0.185520
# dtype: float64

# %%
vertices.max()
# Out:
# 0    0.272844
# 1    0.500000
# 2    0.185520
# dtype: float64

# %%
offset = 600
scale_factor = 1000

# %%
perspective_df = vertices.apply(lambda row: [int(row['x'] * scale_factor) + offset, 
                                             int(row['y'] * scale_factor) + offset, 
                                             int(row['z'] * scale_factor) + offset], axis=1, result_type='expand')
perspective_df.rename(columns={0: 'x', 1: 'y', 2: 'z'}, inplace=True)

# %%
perspective_df
# Out:
#         x     y    z
# 0     543  1090  458
# 1     542  1100  440
# 2     535  1090  453
# 3     550  1099  442
# 4     551  1090  460
# ...   ...   ...  ...
# 7056  647   101  575
# 7057  655   101  575
# 7058  662   101  574
# 7059  670   101  573
# 7060  678   100  572
#
# [7061 rows x 3 columns]

# %%
def draw_line(xs, ys, xe, ye, pixels, values):
    # make sure plot from left to right
    if xe < xs:
        xs, ys, xe, ye = xe, ye, xs, ys
    # whether from top to bottom or bottom to top
    yadd = 1
    if ye < ys:
        yadd = -1
    # if vertical
    if xs == xe:
        for y in range(ys, ye + 1):
            pixels[xs, y] = values
        return
    
    # calculate slope, using abs to avoid negative slope
    m = abs((ye - ys) / (xe - xs))
    # start to plot
    pixels[xs, ys] = values
    # plot along x axis
    if m < 1:
        dx = abs(xe - xs)
        dy = abs(ye - ys)
        dy2 = 2 * dy
        dyx = 2 * (dy - dx)
        
        tmpx = xs
        tmpy = ys
        pk = dy2 - dx
        while tmpx < xe:
            tmpx += 1
            if pk < 0:
                pk += dy2
            else:
                tmpy += yadd
                pk += dyx
            pixels[tmpx, tmpy] = values
    # plot along y axis
    else:
        dx = abs(xe - xs)
        dy = abs(ye - ys)
        dx2 = 2 * dx
        dxy = 2 * (dx - dy)
        
        tmpx = xs
        tmpy = ys
        pk = dx2 - dy
        while tmpx < xe:
            tmpy += yadd
            if pk < 0:
                pk += dx2
            else:
                tmpx += 1
                pk += dxy
            pixels[tmpx, tmpy] = values

# %%
img = Image.new('RGB', (100, 100))
pixels = img.load()
draw_line(0, 99, 20, 0, pixels, (255, 0, 0))
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA033130E20>

# %%
img = Image.new('RGB', (100, 100))
pixels = img.load()
draw_line(20, 0, 0, 99, pixels, (255, 0, 0))
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA03C4F7AC0>

# %%
img = Image.new('RGB', (100, 100))
pixels = img.load()
draw_line(0, 0, 20, 99, pixels, (255, 0, 0))
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA032E28D60>

# %%
img = Image.new('RGB', (100, 100))
pixels = img.load()
draw_line(20, 99, 0, 0, pixels, (255, 0, 0))
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA032E4A7C0>

# %%
img = Image.new('RGB', (100, 100))
pixels = img.load()
draw_line(99, 79, 0, 99, pixels, (255, 0, 0))
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA03C37C520>

# %%
img = Image.new('RGB', (100, 100))
pixels = img.load()
draw_line(0, 99, 99, 79, pixels, (255, 0, 0))
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA03C4F73D0>

# %%
img = Image.new('RGB', (100, 100))
pixels = img.load()
draw_line(0, 0, 99, 20, pixels, (255, 0, 0))
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA032E4A0A0>

# %%
img = Image.new('RGB', (100, 100))
pixels = img.load()
draw_line(99, 20, 0, 0, pixels, (255, 0, 0))
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA03C4F7220>

# %%
img = Image.new('RGB', (100, 100))
pixels = img.load()
draw_line(0, 20, 99, 20, pixels, (255, 0, 0))
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA032E4A730>

# %%
img = Image.new('RGB', (100, 100))
pixels = img.load()
draw_line(50, 0, 50, 99, pixels, (255, 0, 0))
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA03C4F74F0>

# %%
def project_to_img(cur_df, img_size=1200, indices=None):
    img = Image.new('RGB', (img_size, img_size))
    pixels = img.load()
    curnp = cur_df.values
    if indices is None:
        for c1, c2 in curnp:
            pixels[c1, c2] = (255, 0, 0)
    else:
        for p1, p2, p3 in indices.values:
            draw_line(curnp[p1, 0], curnp[p1, 1], curnp[p2, 0], curnp[p2, 1], pixels, (255, 0, 0))
            draw_line(curnp[p1, 0], curnp[p1, 1], curnp[p3, 0], curnp[p3, 1], pixels, (255, 0, 0))
            draw_line(curnp[p3, 0], curnp[p3, 1], curnp[p2, 0], curnp[p2, 1], pixels, (255, 0, 0))
    return img

# %%
xy = project_to_img(perspective_df[['x', 'y']], indices=indices)
xy.show()
xy.save('xy_t.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7FA03C370610>

# %%
yz = project_to_img(perspective_df[['y', 'z']], indices=indices)
yz.show()
yz.save('yz_t.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7FA032E4A850>

# %%
xz = project_to_img(perspective_df[['x', 'z']], indices=indices)
xz.show()
xz.save('xz_t.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7FA033130EE0>

# %%
xy = project_to_img(perspective_df[['x', 'y']])
xy.show()
xy.save('xy.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7FA034330100>

# %%
yz = project_to_img(perspective_df[['y', 'z']])
yz.show()
yz.save('yz.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7FA03C37CA00>

# %%
xz = project_to_img(perspective_df[['x', 'z']])
xz.show()
xz.save('xz.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7FA034377F70>

# %%
from numpy import linspace
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
 
# Creating 3D figure
fig = plt.figure(figsize=(20, 20))
ax = plt.axes(projection='3d')
 
# Creating Dataset
ax.plot3D(vertices['x'], vertices['y'], vertices['z'], 'green')
 
# 360 Degree view
for angle in range(0, 360):
    ax.view_init(angle, 30)
    plt.draw()
    plt.pause(.001)
    plt.show()
